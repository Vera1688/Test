# %%
f = open(
df = pd.read_csv('movies_stats.csv', sep=',')

# %%
years = list(range(1950, 2011))

# %%
def production_year(title):
    for year in years:
        if str(year) in title:
            return year
    return 1900

# %%
df['year'] = df['title'].apply(production_year)

# %%
ratings_by_year = df.groupby('year')['rating'].mean().sort_values(ascending=False)

print(ratings_by_year)
# Out:
# year
# 1957    4.014241
# 1972    4.011136
# 1952    4.000000
# 1954    3.994220
# 1951    3.983539
#           ...
# 2005    3.448434
# 2003    3.444777
# 1996    3.426600
# 1997    3.415764
# 2000    3.356104
# Name: rating, Length: 62, dtype: float64
